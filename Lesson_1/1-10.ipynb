# %%
library(GLMsData)
library(ggplot2)

# %%
data(mandible)

# %%
mandible
# Out:
#     Age  Length
# 1   12.3  8
# 2   12.4  9
# 3   12.7 11
# 4   12.7 11
# 5   12.9 10
# 6   13.1 11
# 7   13.3  9
# 8   13.3 11
# 9   13.6 12
# 10  14.0 11
# 11  14.0 11
# 12  14.0 13
# 13  14.3 16
# 14  14.4 16
# 15  14.6 13
# 16  14.7 14
# 17  14.7 15
# 18  15.0 13
# 19  15.0 15
# 20  15.1 12
# 21  15.1 13
# 22  15.3 13
# 23  15.3 14
# 24  15.6 17
# 25  15.9 17
# 26  16.1 17
# 27  16.1 18
# 28  16.3 14
# 29  16.3 15
# 30  16.3 15
# ... ...  ...
# 138 24.9 31
# 139 25.0 28
# 140 25.0 29
# 141 25.0 32
# 142 25.1 33
# 143 25.3 37
# 144 25.4 33
# 145 25.9 28
# 146 25.9 28
# 147 26.0 31
# 148 26.0 34
# 149 26.6 26
# 150 26.7 40
# 151 26.9 37
# 152 27.0 39
# 153 27.0 41
# 154 27.1 32
# 155 27.6 40
# 156 27.7 35
# 157 27.7 40
# 158 27.9 37
# 159 28.4 38
# 160 28.4 44
# 161 29.0 41
# 162 29.4 38
# 163 29.7 45
# 164 32.0 41
# 165 32.1 32
# 166 32.9 35
# 167 33.6 42

# %%
ggplot(aes(x=Age, y=Length), data=mandible) + geom_smooth() + geom_point()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
